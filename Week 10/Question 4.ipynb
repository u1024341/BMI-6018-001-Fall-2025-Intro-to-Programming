# %% [markdown]
# 4. Find the position of the first occurrence of a value greater than 1.0 in petalwidth 4th column of iris dataset. Use the iris dataset available from https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data

# %%
import numpy as np
import ssl
from urllib.request import urlopen
from io import StringIO

# Create SSL
ssl_context = ssl.create_default_context()
ssl_context.check_hostname = False
ssl_context.verify_mode = ssl.CERT_NONE

# Load iris dataset from URL while preserving text
iris_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
response = urlopen(iris_url, context=ssl_context)
data_text = response.read().decode('utf-8')
iris_data = np.genfromtxt(StringIO(data_text), delimiter=',', dtype=None, encoding=None)

# Question 4: Find the position of the first occurrence of a value greater than 1.0 
# in petalwidth (4th column) of iris dataset 
print("Question 4:")
# Extract the 4th column (petal width) - index 3 from the structured array
petal_width = np.array([row[3] for row in iris_data])
# Find the first position where value > 1.0
position = np.argmax(petal_width > 1.0)
print(f"Position of first occurrence where petal width > 1.0: {position}")
print(f"Value at that position: {petal_width[position]}")
print()
# Out:
# Question 4:
# Position of first occurrence where petal width > 1.0: 50
# Value at that position: 1.4
